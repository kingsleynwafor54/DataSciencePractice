# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-00e10d71e2dd> in <module>
# ----> 1 import pymsql
#
# ModuleNotFoundError: No module named 'pymsql'

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql
connection=pymysql.connect(host='localhost',user='root',password='1234',db='world_x')

# %%
cursor=connection.cursor()

# %%
connection.close() 
import pymysql
import pandas as pd
from sqlalchemy import create_engine

# %%
engine=create_engine("mysql+pymysql://{user}:{pw}@localhost/{db}"
                    .format(user="root",
                           pw="1234",
                           db='world_x'))

# %%
df=pd.read_sql_table('city',con=engine)

# %%
df
# Out:
#         ID            Name CountryCode       District                     Info
# 0        1           Kabul         AFG          Kabol  {'Population': 1780000}
# 1        2        Qandahar         AFG       Qandahar   {'Population': 237500}
# 2        3           Herat         AFG          Herat   {'Population': 186800}
# 3        4  Mazar-e-Sharif         AFG          Balkh   {'Population': 127800}
# 4        5       Amsterdam         NLD  Noord-Holland   {'Population': 731200}
# ...    ...             ...         ...            ...                      ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis   {'Population': 123175}
# 4075  4076          Hebron         PSE         Hebron   {'Population': 119401}
# 4076  4077        Jabaliya         PSE     North Gaza   {'Population': 113901}
# 4077  4078          Nablus         PSE         Nablus   {'Population': 100231}
# 4078  4079           Rafah         PSE          Rafah    {'Population': 92020}
#
# [4079 rows x 5 columns]

# %%
query='''select * from city'''
df=pd.read_sql_query(query,con=engine)

# %%
df
# Out:
#         ID            Name CountryCode       District                     Info
# 0        1           Kabul         AFG          Kabol  {"Population": 1780000}
# 1        2        Qandahar         AFG       Qandahar   {"Population": 237500}
# 2        3           Herat         AFG          Herat   {"Population": 186800}
# 3        4  Mazar-e-Sharif         AFG          Balkh   {"Population": 127800}
# 4        5       Amsterdam         NLD  Noord-Holland   {"Population": 731200}
# ...    ...             ...         ...            ...                      ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis   {"Population": 123175}
# 4075  4076          Hebron         PSE         Hebron   {"Population": 119401}
# 4076  4077        Jabaliya         PSE     North Gaza   {"Population": 113901}
# 4077  4078          Nablus         PSE         Nablus   {"Population": 100231}
# 4078  4079           Rafah         PSE          Rafah    {"Population": 92020}
#
# [4079 rows x 5 columns]

# %%
df=pd.read_sql_query('''select * from city''',con=engine)

# %%
df
# Out:
#         ID            Name CountryCode       District                     Info
# 0        1           Kabul         AFG          Kabol  {"Population": 1780000}
# 1        2        Qandahar         AFG       Qandahar   {"Population": 237500}
# 2        3           Herat         AFG          Herat   {"Population": 186800}
# 3        4  Mazar-e-Sharif         AFG          Balkh   {"Population": 127800}
# 4        5       Amsterdam         NLD  Noord-Holland   {"Population": 731200}
# ...    ...             ...         ...            ...                      ...
# 4074  4075      Khan Yunis         PSE     Khan Yunis   {"Population": 123175}
# 4075  4076          Hebron         PSE         Hebron   {"Population": 119401}
# 4076  4077        Jabaliya         PSE     North Gaza   {"Population": 113901}
# 4077  4078          Nablus         PSE         Nablus   {"Population": 100231}
# 4078  4079           Rafah         PSE          Rafah    {"Population": 92020}
#
# [4079 rows x 5 columns]

# %%
query2="""select c.Code, c.Name, cl.Language, cl.IsOfficial
from country as c
left join countrylanguage as cl
on c.Code=cl.CountryCode
where c.Code='NGA';"""

# %%
df1=pd.read_sql(query2,con=engine)

# %%
df1
# Out:
#   Code     Name Language IsOfficial
# 0  NGA  Nigeria     Bura          F
# 1  NGA  Nigeria      Edo          F
# 2  NGA  Nigeria      Ful          F
# 3  NGA  Nigeria    Hausa          F
# 4  NGA  Nigeria   Ibibio          F
# 5  NGA  Nigeria      Ibo          F
# 6  NGA  Nigeria      Ijo          F
# 7  NGA  Nigeria   Joruba          F
# 8  NGA  Nigeria   Kanuri          F
# 9  NGA  Nigeria      Tiv          F

# %% [markdown]
# ## How to write back to the database

# %%
df1.to_sql("nigeria_lang",con=engine,index=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-45679ceed06e> in <module>
# ----> 1 df1.to_sql("nigeria_lang",con=engine,index=False)
#       2 df2=pd.read_sql("nigeria_lang",con=engine)
#       3 df2
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# ~\anaconda3\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     599         )
#     600
# --> 601     pandas_sql.to_sql(
#     602         frame,
#     603         name,
#
# ...

# %%
df2=pd.read_sql("nigeria_lang",con=engine)
df2
# Out:
#   Code     Name Language IsOfficial
# 0  NGA  Nigeria     Bura          F
# 1  NGA  Nigeria      Edo          F
# 2  NGA  Nigeria      Ful          F
# 3  NGA  Nigeria    Hausa          F
# 4  NGA  Nigeria   Ibibio          F
# 5  NGA  Nigeria      Ibo          F
# 6  NGA  Nigeria      Ijo          F
# 7  NGA  Nigeria   Joruba          F
# 8  NGA  Nigeria   Kanuri          F
# 9  NGA  Nigeria      Tiv          F

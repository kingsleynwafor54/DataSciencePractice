# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(np.random.randn(1000,4),columns=list('ABCD'))

# %%
df.describe()
# Out:
#                  A            B            C            D
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     -0.020095     0.033287     0.008150    -0.016451
# std       1.000431     0.999646     1.005789     0.989806
# min      -3.763075    -3.027035    -3.087739    -3.378732
# 25%      -0.646741    -0.657232    -0.698151    -0.639600
# 50%      -0.018229     0.010446     0.037687     0.017720
# 75%       0.591525     0.710782     0.726074     0.659961
# max       3.150751     3.256176     3.583534     3.609425

# %%
df.head()
# Out:
#           A         B         C         D
# 0  0.742658  1.170129  1.370647  0.911192
# 1  0.336035 -0.138328 -0.286944 -0.367834
# 2  0.907164  0.054071 -0.921890  0.535421
# 3  0.252862  0.748728  1.096908 -1.268680
# 4 -0.268691 -0.012715 -0.336447  0.737420

# %%
# Scatter Plot
df.plot.scatter(x='A',y='B',c='c')
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
# Hexagonal Bin Plot

# %%
df.plot.hexbin(x='A',y='B',gridsize=10)
# Out:
# <AxesSubplot:xlabel='A', ylabel='B'>

# %%
# A box plot helps you to dictect outlier,by showing the distribution of numerical data and showness through displaying the data quartiles

# %%
df.plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Seaborn visualisation

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('fivethirtyeight')
import warnings
warnings.filterwarnings('ignore')

# %%
data=sns.load_dataset('iris')
data1=sns.

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df=pd.read_csv('iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
sns.distplot(data['sepal_length'])
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.jointplot(x='sepal_length',y="sepal_width",data=data)

# %%
sns.jointplot(x='sepal_length',y="sepal_width",data=data,kind='hex')

# %%
sns.boxplot(x='species',y='sepal_length',data=data)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.violinplot(y='sepal_length',x="species",data=data)
# Out:
# <AxesSubplot:xlabel='species', ylabel='sepal_length'>

# %%
sns.pairplot(data=data,kind='scatter',hue='species')

# %% [markdown]
# ### HeatMap

# %% [markdown]
# It is used to find correllation in dataset

# %%
sns.heatmap(data.corr(),annot=True,cmap='inferno')
# Out:
# <AxesSubplot:>
